# %% [markdown]
# # 😴 Sleep Alarm Detector
#
# A real-time drowsiness detection system built using **OpenCV** and **MediaPipe**. The project monitors eye closure using the Eye Aspect Ratio (EAR) and triggers an alarm when the user's eyes remain closed for too long.

# %% [markdown]
# # Imports
#
# This section imports all the required libraries for computer vision, face landmark detection, numerical computation, threading, and alarm functionality.

# %%
pip install opencv-python mediapipe numpy notebook
# Out:
# Collecting opencv-python
#   Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting mediapipe
#   Using cached mediapipe-0.10.35-py3-none-win_amd64.whl.metadata (9.8 kB)
# Collecting numpy
#   Using cached numpy-2.5.1-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: notebook in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (7.5.5)
# Collecting absl-py~=2.3 (from mediapipe)
#   Downloading absl_py-2.5.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: certifi in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mediapipe) (2026.2.25)
# Collecting sounddevice~=0.5 (from mediapipe)
#   Downloading sounddevice-0.5.5-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting flatbuffers~=25.9 (from mediapipe)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting matplotlib (from mediapipe)
#   Downloading matplotlib-3.11.0-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Requirement already satisfied: cffi in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sounddevice~=0.5->mediapipe) (2.0.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.6 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from notebook) (4.5.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from notebook) (6.5.5)
# Requirement already satisfied: anyio>=3.1.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: packaging>=22.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.0)
# Requirement already satisfied: prometheus-client>=0.9 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: pyzmq>=24 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (7.2.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (82.0.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (1.0.9)
# Requirement already satisfied: idna in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: requests>=2.31 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.32.5)
# Requirement already satisfied: argon2-cffi-bindings in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (9.11.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (7.2.2)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.8.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.9.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.3.0)
# Requirement already satisfied: defusedxml in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: webencodings in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: six>=1.5 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.2.3)
# Requirement already satisfied: pycparser in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from cffi->sounddevice~=0.5->mediapipe) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: tzdata in C:\Users\lapto\AppData\Local\Programs\Python\Python314\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.3)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapipe)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mediapipe)
#   Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapipe)
#   Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Collecting pillow>=9 (from matplotlib->mediapipe)
#   Downloading pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib->mediapipe)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Downloading opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3
#    ------------------------ --------------- 32.5/53.8 MB 3.6 MB/s eta 0:00:06
#    ------------------------ --------------- 33.3/53.8 MB 3.6 MB/s eta 0:00:06
#    ------------------------- -------------- 34.3/53.8 MB 3.6 MB/s eta 0:00:06
#    -------------------------- ------------- 35.1/53.8 MB 3.7 MB/s eta 0:00:06
#    -------------------------- ------------- 36.2/53.8 MB 3.7 MB/s eta 0:00:05
#    --------------------------- ------------ 37.0/53.8 MB 3.7 MB/s eta 0:00:05
#    ---------------------------- ----------- 38.0/53.8 MB 3.7 MB/s eta 0:00:05
#    ----------------------------- ---------- 39.1/53.8 MB 3.7 MB/s eta 0:00:04
#    ----------------------------- ---------- 40.1/53.8 MB 3.7 MB/s eta 0:00:04
#    ------------------------------ --------- 40.9/53.8 MB 3.7 MB/s eta 0:00:04
#    ------------------------------- -------- 41.9/53.8 MB 3.8 MB/s eta 0:00:04
#    ------------------------------- -------- 42.7/53.8 MB 3.8 MB/s eta 0:00:03
#    -------------------------------- ------- 43.8/53.8 MB 3.8 MB/s eta 0:00:03
#    --------------------------------- ------ 44.8/53.8 MB 3.8 MB/s eta 0:00:03
#    --------------------------------- ------ 45.6/53.8 MB 3.8 MB/s eta 0:00:03
#    ---------------------------------- ----- 46.4/53.8 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 47.2/53.8 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 48.0/53.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 48.8/53.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 49.5/53.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 50.6/53.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 51.4/53.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 52.4/53.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  53.2/53.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  53.7/53.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 53.8/53.8 MB 3.8 MB/s  0:00:14
# Installing collected packages: flatbuffers, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, absl-py, sounddevice, opencv-python, opencv-contrib-python, contourpy, matplotlib, mediapipe
#
#    ----------------------------------------  0/14 [flatbuffers]
#    -- -------------------------------------  1/14 [pyparsing]
#    -- -------------------------------------  1/14 [pyparsing]
#    -- -------------------------------------  1/14 [pyparsing]
#    -- -------------------------------------  1/14 [pyparsing]
#    -- -------------------------------------  1/14 [pyparsing]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    ----- ----------------------------------  2/14 [pillow]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    -------- -------------------------------  3/14 [numpy]
#    ----------- ----------------------------  4/14 [kiwisolver]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    -------------- -------------------------  5/14 [fonttools]
#    ----------------- ----------------------  6/14 [cycler]
#    -------------------- -------------------  7/14 [absl-py]
#    -------------------- -------------------  7/14 [absl-py]
#    -------------------- -------------------  7/14 [absl-py]
#    -------------------- -------------------  7/14 [absl-py]
#    ---------------------- -----------------  8/14 [sounddevice]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ------------------------- --------------  9/14 [opencv-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ---------------------------- ----------- 10/14 [opencv-contrib-python]
#    ------------------------------- -------- 11/14 [contourpy]
#    ------------------------------- -------- 11/14 [contourpy]
#    ------------------------------- -------- 11/14 [contourpy]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ---------------------------------- ----- 12/14 [matplotlib]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ------------------------------------- -- 13/14 [mediapipe]
#    ---------------------------------------- 14/14 [mediapipe]
#
# Successfully installed absl-py-2.5.0 contourpy-1.3.3 cycler-0.12.1 flatbuffers-25.12.19 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 mediapipe-0.10.35 numpy-2.5.1 opencv-contrib-python-5.0.0.93 opencv-python-5.0.0.93 pillow-12.3.0 pyparsing-3.3.2 sounddevice-0.5.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\lapto\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
import sys

print(sys.executable)
# Out:
# C:\Users\lapto\AppData\Local\Programs\Python\Python314\python.exe

# %%
# Import libraries required for computer vision, face detection, and alarm functionality.

import cv2
import mediapipe as mp
import numpy as np
import time
import os
import threading
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Constants
#
# This section defines the threshold values, eye landmark indices, and alarm configuration used throughout the project.

# %%
# ==========================
# Project Constants
# ==========================

# Threshold below which the eyes are considered closed.
EAR_THRESHOLD = 0.22

# Time (in seconds) the eyes must remain closed before triggering the alarm.
EYE_CLOSED_SECONDS = 2.5

# Alarm sound file path.
ALARM_SOUND_FILE = "dragon-studio-censor-beep-3-372460.mp3"

# MediaPipe landmark indices for the left and right eyes.
LEFT_EYE_INDICES = [362, 385, 387, 263, 373, 380]
RIGHT_EYE_INDICES = [33, 160, 158, 133, 153, 144]

# %% [markdown]
# # Eye Aspect Ratio (EAR)
#
# Calculate the Eye Aspect Ratio (EAR) using facial landmarks to determine whether the eyes are open or closed.

# %%
# =====================================
# Calculate Eye Aspect Ratio (EAR)
# =====================================

# Calculate the Eye Aspect Ratio (EAR) using eye landmarks.
def eye_aspect_ratio(landmarks, eye_indices, frame_w, frame_h):
    # Store the coordinates of eye landmarks.
    pts = []

    # Compute the vertical and horizontal eye distances.
    for idx in eye_indices:
        lm = landmarks[idx]
        pts.append(np.array([lm.x * frame_w, lm.y * frame_h]))

    A = np.linalg.norm(pts[1] - pts[5])
    B = np.linalg.norm(pts[2] - pts[4])
    C = np.linalg.norm(pts[0] - pts[3])

    ear = (A + B) / (2.0 * C)

    # Return the calculated EAR value.
    return ear

# %% [markdown]
# # Alarm Functions
#
# These functions are responsible for playing and stopping the alarm when prolonged eye closure is detected.

# %%
def play_alarm():
    """Trigger a simple alert when drowsiness is detected."""
    print("\a")      # Console beep
    print("ALERT! Drowsiness detected.")

# %% [markdown]
# # Display Functions
#
# Draw the status overlay, face bounding box, and display real-time information on the video frame.

# %%
# Draw the status banner and real-time information on the frame.
def draw_status_overlay(frame, alarm_active, elapsed, ear_avg):
    h, w = frame.shape[:2]
    if alarm_active:
        color = (0, 0, 220)
        bg_color = (0, 0, 180)
        label = "SLEEPING! WAKE UP!"
        icon = "😴"
    else:
        color = (0, 200, 50)
        bg_color = (0, 150, 40)
        label = "AWAKE"
        icon = "👁️"
    if alarm_active:
        pulse = int(abs(np.sin(time.time() * 4)) * 80)
        overlay = frame.copy()
        cv2.rectangle(overlay, (0, 0), (w, h), (0, 0, 255), -1)
        cv2.addWeighted(overlay, 0.20 + pulse / 1000, frame, 0.80 - pulse / 1000, 0, frame)
    pill_w, pill_h = 340, 54
    pill_x = (w - pill_w) // 2
    pill_y = 14
    cv2.rectangle(frame, (pill_x, pill_y), (pill_x + pill_w, pill_y + pill_h), bg_color, -1, cv2.LINE_AA)
    cv2.rectangle(frame, (pill_x, pill_y), (pill_x + pill_w, pill_y + pill_h), color, 2, cv2.LINE_AA)
    cv2.putText(frame, label, (pill_x + 20, pill_y + 36), cv2.FONT_HERSHEY_DUPLEX, 0.9, (255, 255, 255), 2, cv2.LINE_AA)
    dot_x = pill_x - 30
    dot_y = pill_y + pill_h // 2
    cv2.circle(frame, (dot_x, dot_y), 14, color, -1, cv2.LINE_AA)
    cv2.circle(frame, (dot_x, dot_y), 14, (255, 255, 255), 2, cv2.LINE_AA)
    bar_h = 50
    bar_y = h - bar_h
    cv2.rectangle(frame, (0, bar_y), (w, h), (20, 20, 20), -1)
    ear_text = f"EAR: {ear_avg:.3f}  (thresh: {EAR_THRESHOLD})"
    closed_text = f"Eyes closed: {elapsed:.1f}s / {EYE_CLOSED_SECONDS}s"
    cv2.putText(frame, ear_text, (14, bar_y + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (200, 200, 200), 1, cv2.LINE_AA)
    cv2.putText(frame, closed_text, (14, bar_y + 40), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (200, 200, 200), 1, cv2.LINE_AA)
    if elapsed > 0 and not alarm_active:
        progress = min(elapsed / EYE_CLOSED_SECONDS, 1.0)
        bar_fill_w = int((w - 28) * progress)
        cv2.rectangle(frame, (14, bar_y + 45), (14 + bar_fill_w, bar_y + 49), (0, 165, 255), -1, cv2.LINE_AA)
    return frame

# %%
# Draw a bounding box around the detected face.
def draw_face_box(frame, landmarks, color, w, h):
    xs = [int(lm.x * w) for lm in landmarks]
    ys = [int(lm.y * h) for lm in landmarks]
    pad = 10
    x1, y1 = max(0, min(xs) - pad), max(0, min(ys) - pad)
    x2, y2 = min(w, max(xs) + pad), min(h, max(ys) + pad)
    cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2, cv2.LINE_AA)
    corner = 18
    thick = 3
    for cx, cy, dx, dy in [(x1,y1,1,1),(x2,y1,-1,1),(x1,y2,1,-1),(x2,y2,-1,-1)]:
        cv2.line(frame, (cx, cy), (cx + dx*corner, cy), color, thick, cv2.LINE_AA)
        cv2.line(frame, (cx, cy), (cx, cy + dy*corner), color, thick, cv2.LINE_AA)

# %% [markdown]
# # Face Detection Initialization
#
# Initialize the MediaPipe Face Mesh model to detect facial landmarks from the webcam stream.

# %%
# =====================================
# Initialize MediaPipe Face Mesh
# =====================================

mp_face_mesh = mp.solutions.face_mesh

face_mesh = mp_face_mesh.FaceMesh(
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.6,
    min_tracking_confidence=0.6,
)

# %% [markdown]
# # Main Detection Loop
#
# Capture webcam frames, detect eye closure, calculate the EAR, trigger the alarm when required, and display the processed output.

# %%
def main():
    # Initialize the MediaPipe Face Mesh model
    mp_face_mesh = mp.solutions.face_mesh
    face_mesh = mp_face_mesh.FaceMesh(
        max_num_faces=1,
        refine_landmarks=True,
        min_detection_confidence=0.6,
        min_tracking_confidence=0.6,
    )

    # Open the default webcam
    cap = cv2.VideoCapture(0)

    # Exit if the webcam cannot be accessed
    if not cap.isOpened():
        print("[ERROR] Cannot open webcam.")
        return

    # Set webcam resolution
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

    # Initialize variables for eye closure tracking
    eye_closed_start = None
    alarm_active = False
    alarm_thread = None

    # Record the session start time
    session_start_time = time.time()

    # Display project information
    print("=" * 60)
    print("  Sleep Detector — press Q to quit")
    print(f"  Alarm fires after {EYE_CLOSED_SECONDS}s of closed eyes")
    if PYGAME_AVAILABLE:
        print(f"  Looking for alarm sound: {ALARM_SOUND_FILE}")
    print("=" * 60)

    # Start capturing webcam frames
    while True:
        ret, frame = cap.read()

        # Exit if frame capture fails
        if not ret:
            break

        # Flip the frame for a mirror-like view
        frame = cv2.flip(frame, 1)

        # Get frame dimensions
        h, w = frame.shape[:2]

        # Convert frame from BGR to RGB
        rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Detect facial landmarks
        results = face_mesh.process(rgb)

        # Default values
        ear_avg = 1.0
        elapsed = 0.0
        face_detected = False

        # Calculate total session duration
        session_time = int(time.time() - session_start_time)
        minutes = session_time // 60
        seconds = session_time % 60

        # Check if a face is detected
        if results.multi_face_landmarks:

            face_detected = True

            # Extract face landmarks
            lms = results.multi_face_landmarks[0].landmark

            # Calculate EAR for both eyes
            ear_l = eye_aspect_ratio(lms, LEFT_EYE_INDICES, w, h)
            ear_r = eye_aspect_ratio(lms, RIGHT_EYE_INDICES, w, h)

            # Compute average EAR
            ear_avg = (ear_l + ear_r) / 2.0

            # Determine whether the eyes are closed
            eyes_closed = ear_avg < EAR_THRESHOLD

            if eyes_closed:

                # Record the time when eyes first close
                if eye_closed_start is None:
                    eye_closed_start = time.time()

                # Calculate how long the eyes have remained closed
                elapsed = time.time() - eye_closed_start

                # Trigger the alarm after the threshold duration
                if elapsed >= EYE_CLOSED_SECONDS and not alarm_active:
                    alarm_active = True
                    alarm_thread = threading.Thread(target=play_alarm, daemon=True)
                    alarm_thread.start()

            else:
                # Reset timer when eyes reopen
                eye_closed_start = None

                # Stop the alarm if it is currently active
                if alarm_active:
                    alarm_active = False
                    stop_alarm()

            # Change face box color based on alarm status
            face_color = (0, 0, 220) if alarm_active else (0, 220, 60)

            # Draw a bounding box around the detected face
            draw_face_box(frame, lms, face_color, w, h)

        else:
            # Reset everything if no face is detected
            eye_closed_start = None

            if alarm_active:
                alarm_active = False
                stop_alarm()

        # Draw the status overlay
        frame = draw_status_overlay(frame, alarm_active, elapsed, ear_avg)

        # Display session timer
        timer_text = f"Session Time: {minutes:02d}:{seconds:02d}"

        (text_w, text_h), _ = cv2.getTextSize(
            timer_text,
            cv2.FONT_HERSHEY_SIMPLEX,
            0.7,
            2,
        )

        cv2.putText(
            frame,
            timer_text,
            (w - text_w - 20, 35),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.7,
            (255, 255, 0),
            2,
            cv2.LINE_AA,
        )

        # Display a message when no face is detected
        if not face_detected:
            cv2.putText(
                frame,
                "No face detected",
                (w // 2 - 130, h // 2),
                cv2.FONT_HERSHEY_DUPLEX,
                1.0,
                (0, 180, 255),
                2,
                cv2.LINE_AA,
            )

        # Display the processed frame
        cv2.imshow("Sleep Alarm Detector", frame)

        # Exit the application when 'Q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release resources and close all windows
    stop_alarm()
    cap.release()
    face_mesh.close()
    cv2.destroyAllWindows()

# %% [markdown]
# # Execute the Project
#
# Run the `main()` function to start the real-time sleep detection system. Press **Q** to exit the application.

# %%
# =====================================
# Run the project
# =====================================

if __name__ == "__main__":
    main()

# %% [markdown]
# # Conclusion
#
# This project demonstrates how computer vision techniques can be used to build a simple and effective real-time drowsiness detection system using OpenCV and MediaPipe.
